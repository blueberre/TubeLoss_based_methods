# %% [markdown]
# # Compile Results: Side-by-side delta plots
#
# Run this notebook after running your benchmark experiments. It prints the calibration comparison tables and displays one side-by-side plot per dataset: delta vs PICP and delta vs MPIW.

# %%
# Run this after running your experiments, e.g.:
# python run_experiment.py --benchmarks

# !python compile_results.py
# Out:
# Loaded datasets: boston, concrete, energy, protein, wine, synthetic, power, yacht
# Wrote calibration CSV table to compiled_results\calib_side_by_side_comparison_table.csv
# Wrote printed tables to compiled_results\calib_side_by_side_printed_tables.txt
# Wrote TubeLoss delta target summary to compiled_results\delta_target_summary.txt
# Wrote side-by-side delta plots to compiled_results\plots\delta_side_by_side
#
# TubeLoss delta for calibration PICP target — boston
#   target PICP        : 0.9000
#   reported delta     : 0.0191  (interpolated)
#   exact grid delta   : none within ±0.0005
#   interpolated delta : 0.0191
#   closest grid delta : 0.0130 (PICP=0.9010, |diff|=0.0010)
#
# Dataset: boston
# ...
#                    Tubeloss                                 Quantile
#     method_name     PICP     MPIW    q_hat   method_name     PICP     MPIW    q_hat
# 0   Tube Loss     0.9010  24.6090      NaN   Pinball Loss  0.9109  27.1111      NaN
# ...

# %%
from pathlib import Path
from IPython.display import Image, display

plot_dir = Path('compiled_results/plots/delta_side_by_side')
plot_files = sorted(plot_dir.glob('*_delta_picp_mpiw_side_by_side.png'))

if not plot_files:
    print('No side-by-side delta plots found. Run the previous cell first.')
else:
    for plot_file in plot_files:
        print(plot_file.name)
        display(Image(filename=str(plot_file)))
# Out:
# boston_delta_picp_mpiw_side_by_side.png
# concrete_delta_picp_mpiw_side_by_side.png
# energy_delta_picp_mpiw_side_by_side.png
# power_delta_picp_mpiw_side_by_side.png
# protein_delta_picp_mpiw_side_by_side.png
# synthetic_delta_picp_mpiw_side_by_side.png
# wine_delta_picp_mpiw_side_by_side.png
# yacht_delta_picp_mpiw_side_by_side.png
